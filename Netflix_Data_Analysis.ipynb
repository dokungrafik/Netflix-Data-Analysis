# %%
# Import libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Dokungrafik\Documents\MyProjects\Netflix_Dataset\Netflix_Dataset.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# #### Getting some basic information about the dataset

# %% [markdown]
# ##### 1. The first 20 records of the Dataset

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %% [markdown]
# ##### 2. The last 20 records of the Dataset

# %%
data.tail(20)
# Out:
#      Show_Id Category                                    Title  \
# 7769   s7768  TV Show                       Zindagi Gulzar Hai
# 7770   s7769    Movie                 Zindagi Kitni Haseen Hay
# 7771   s7770    Movie                 Zindagi Na Milegi Dobara
# 7772   s7771    Movie                                  Zinzana
# 7773   s7772    Movie                                     Zion
# 7774   s7773    Movie        Zipi & Zape y la Isla del Capitan
# 7775   s7774    Movie                           Zoé: Panoramas
# 7776   s7775    Movie                                   Zodiac
# 7777   s7776  TV Show                               Zoids Wild
# 7778   s7777    Movie                                 Zokkomon
# 7779   s7778  TV Show                              Zombie Dumb
# 7780   s7779    Movie                               Zombieland
# 7781   s7780  TV Show                                Zona Rosa
# 7782   s7781    Movie                                      Zoo
# ...

# %% [markdown]
# ##### 3. Show the number of Rows and Columns

# %%
data.shape
# Out:
# (7789, 11)

# %%
print('Number of Rows', data.shape[0])
print('Number of Columns', data.shape[1])
# Out:
# Number of Rows 7789
# Number of Columns 11

# %% [markdown]
# ##### 4. Show each of the Columns name

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ##### 5. Show the Number of values (elements) in the Dataset

# %%
data.size
# Out:
# 85679

# %% [markdown]
# ##### 6. Show the basic info of the Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ##### 7. Show the datatypes of each column

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ##### Task 1. Is there any Duplicate Record in this Dataset? If yes, then remove the Duplicate records.

# %%
 data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
# To check the Rows and detect the Duplicate Rows
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# To remove the duplicate Rows permanently
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ##### Task 2. Is there any Null Value present in any column ? Show with Heat-map.

# %%
# To show where Null value is present in the Dataset
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
# To show the count of Null Values in each column
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# To use heat map to show the Null values count
sns.heatmap(data.isnull())
plt.title("Null Value Count with Heatmap")
plt.show()

# %% [markdown]
# ##### Question (1). For 'Code 8', what is the Show Id and Who is the Director of this show ?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# To show all records of a particular item in a column using isin() funtion
data[data["Title"].isin(["Code 8"])]
# Out:
#      Show_Id Category   Title   Director  \
# 1446   s1447    Movie  Code 8  Jeff Chan
#
#                                                    Cast Country  \
# 1446  Robbie Amell, Stephen Amell, Sung Kang, Kari M...  Canada
#
#         Release_Date Rating Duration  \
# 1446  April 11, 2020  TV-MA   98 min
#
#                                                    Type  \
# 1446  Action & Adventure, Independent Movies, Intern...
#
#                                             Description
# 1446  In a city where super-powered people are ostra...

# %%
# To show all records of a particular item in a column using str.contains() funtion
data[data["Title"].str.contains("Code 8")]
# Out:
#      Show_Id Category   Title   Director  \
# 1446   s1447    Movie  Code 8  Jeff Chan
#
#                                                    Cast Country  \
# 1446  Robbie Amell, Stephen Amell, Sung Kang, Kari M...  Canada
#
#         Release_Date Rating Duration  \
# 1446  April 11, 2020  TV-MA   98 min
#
#                                                    Type  \
# 1446  Action & Adventure, Independent Movies, Intern...
#
#                                             Description
# 1446  In a city where super-powered people are ostra...

# %% [markdown]
# ##### Question (2) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#To create a new column and convert the Release_Date column using datetime() function
# date string
data['Release_Date'] = "August 14, 2020"
data["Date_N"] = pd.to_datetime(data["Release_Date"])

# %%
# To count the occurence of all individual years in each column using dt.year.value_counts() function
data["Date_N"].dt.year.value_counts()
# Out:
# Date_N
# 2020    7787
# Name: count, dtype: int64

# %%
# Plotting Graph
data["Date_N"].dt.year.value_counts().plot(kind='bar')
plt.title("Number of TV Shows and Movies")
plt.show()

# %% [markdown]
# ##### Question (3) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#       Release_Date Rating   Duration  \
# 0  August 14, 2020  TV-MA  4 Seasons
# 1  August 14, 2020  TV-MA     93 min
# 2  August 14, 2020      R     78 min
# 3  August 14, 2020  PG-13     80 min
# 4  August 14, 2020  PG-13    123 min
#
# ...

# %%
# To group all unique items of a columns and show their counts using groupby()
data.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# To show the count of all unique items of a column in form of Bar graph
#sns.countplot(data["Category"])

# %% [markdown]
# ##### Question (4) Show all the Movies that were released in year 2000.

# %% [markdown]
# ##### Creating New Column

# %%
#show our first 2 data in the dataset
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14

# %%
# To create a Year column which will consider only Year Column
data["Year"] = data["Date_N"].dt.year

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
#Filtering the data to show only movies that were released in year 2000
data [ (data["Category"] == "Movie") & (data["Year"] == "2020") ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# ##### Question (5) Show only the Titles of all TV Shows that were released in India only.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
data [ (data["Category"] == "TV Show") & (data["Country"] == "India") ] ["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ##### Question (6) Show Top 20 Directors who gave the highest number of TV Shows & Movies to Netflix ?

# %%
# To show the first 2 data in the Dataset
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
data["Director"].value_counts().head(20)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Lance Bangs                8
# Kunle Afolayan             8
# Ryan Polito                8
# Shannon Hartman            8
# Johnnie To                 8
# Quentin Tarantino          8
# Robert Rodriguez           8
# Omoni Oboli                7
# McG                        7
# Fernando Ayllón            7
# Name: count, dtype: int64

# %% [markdown]
# ##### Question (7) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
# Filtering using And, Or Operators)
# using And Operator
data[ (data['Category'] == "Movie") & (data["Type"] == "Comedies") ].head()
# Out:
#     Show_Id Category                        Title                Director  \
# 33      s34    Movie                 #realityhigh        Fernando Lebrija
# 72      s73    Movie                     17 Again             Burr Steers
# 84      s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148    s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174    s175    Movie  A Futile and Stupid Gesture              David Wain
#
#                                                   Cast               Country  \
# 33   Nesta Cooper, Kate Walsh, John Michael Higgins...         United States
# 72   Zac Efron, Leslie Mann, Matthew Perry, Thomas ...         United States
# 84   Miles Teller, Skylar Astin, Justin Chon, Sarah...         United States
# 148  Mila Kunis, Kristen Bell, Kathryn Hahn, Susan ...  United States, China
# 174  Will Forte, Domhnall Gleeson, Martin Mull, Joe...         United States
#
#         Release_Date Rating Duration      Type  \
# ...

# %%
# using or Operator
data[ (data['Category'] == "Movie") & (data["Type"] == "Comedies") | (data["Country"] == "United Kingdom")].head()
# Out:
#    Show_Id Category                Title          Director  \
# 19     s20    Movie                  '89               NaN
# 33     s34    Movie         #realityhigh  Fernando Lebrija
# 58     s59  TV Show          100% Hotter               NaN
# 72     s73    Movie             17 Again       Burr Steers
# 82     s83    Movie  2036 Origin Unknown     Hasraf Dulull
#
#                                                  Cast         Country  \
# 19                 Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# 58  Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
# 72  Zac Efron, Leslie Mann, Matthew Perry, Thomas ...   United States
# 82  Katee Sackhoff, Ray Fearon, Julie Cox, Steven ...  United Kingdom
#
#        Release_Date Rating  Duration  \
# 19  August 14, 2020  TV-PG    87 min
# 33  August 14, 2020  TV-14    99 min
# 58  August 14, 2020  TV-14  1 Season
# ...

# %% [markdown]
# ##### Question (8) In how many movies/shows, Tom Cruise was cast?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %% [markdown]
# ##### Filtering

# %%
data[data["Cast"] == "Tom Cruise"]          # To check for a cast that contains only Tom Cruise
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
# using str.contains To check for a cast that contains Tom Cruise
data[data["Cast"].str.contains("Tom Cruise")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 # using str.contains To check for a cast that contains Tom Cruise
# ----> 2 data[data["Cast"].str.contains("Tom Cruise")]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %% [markdown]
# ##### Create a New Data Frame and remove the null Values

# %%
# To drop the rows that contains all or any missing values
new_data = data.dropna()

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#       Release_Date Rating   Duration  \
# 0  August 14, 2020  TV-MA  4 Seasons
# 1  August 14, 2020  TV-MA     93 min
# 2  August 14, 2020      R     78 min
# 3  August 14, 2020  PG-13     80 min
# 4  August 14, 2020  PG-13    123 min
#
# ...

# %%
new_data[new_data["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  August 14, 2020      R  189 min  Dramas, Independent Movies
# 5071  August 14, 2020      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N  Year
# 3860  Through chance, human action, past history and... 2020-08-14  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2020-08-14  2020

# %% [markdown]
# ##### Question (9) What are the different Ratings defined by Netflix?

# %% [markdown]
# ##### Two (2) functions will be used which are: nunique and unique

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
# Using nunique function
data.Rating.nunique()
# Out:
# 14

# %%
# Using unique function
data.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ##### Question (9.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
data[(data["Category"] == "Movie") & (data["Rating"] == "TV-14")].head()         # To show the first 5
# Out:
#    Show_Id Category                 Title            Director  \
# 8       s9    Movie                   706       Shravan Kumar
# 15     s16    Movie                Oct-01      Kunle Afolayan
# 18     s19    Movie                15-Aug  Swapnaneel Jayakar
# 20     s21    Movie  ​​Kuch Bheege Alfaaz                Onir
# 21     s22    Movie          ​Goli Soda 2        Vijay Milton
#
#                                                  Cast  Country  \
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...    India
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...  Nigeria
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...    India
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...    India
# 21  Samuthirakani, Bharath Seeni, Vinoth, Esakki B...    India
#
#        Release_Date Rating Duration  \
# 8   August 14, 2020  TV-14  118 min
# 15  August 14, 2020  TV-14  149 min
# 18  August 14, 2020  TV-14  124 min
# 20  August 14, 2020  TV-14  110 min
# ...

# %%
data[(data["Category"] == "Movie") & (data["Rating"] == "TV-14")].shape
# Out:
# (1272, 13)

# %%
 data[(data["Category"] == "Movie") & (data["Rating"] == "TV-14") & (data["Country"] == "Canada")].head()        # To show the first 5
# Out:
#      Show_Id Category                       Title  \
# 30       s31    Movie            #cats_the_mewvie
# 34       s35    Movie                       #Roxy
# 608     s609    Movie              At First Light
# 1506   s1507    Movie  Counterfeiting in Suburbia
# 3713   s3714    Movie           Long Time Running
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
#
#                                                    Cast Country  \
# 30                                                  NaN  Canada
# 34    Jake Short, Sarah Fisher, Booboo Stewart, Dann...  Canada
# 608   Stefanie Scott, Theodore Pellerin, Percy Hynes...  Canada
# 1506  Sarah Butler, Larissa Albuquerque, Kayla Walla...  Canada
# ...

# %%
data[(data["Category"] == "Movie") & (data["Rating"] == "TV-14") & (data["Country"] == "Canada")].shape
# Out:
# (11, 13)

# %% [markdown]
# ##### Question (9.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
data[(data["Category"] == "TV Show") & (data["Rating"] == "R")]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#          Release_Date Rating  Duration  \
# 4497  August 14, 2020      R  1 Season
# 6437  August 14, 2020      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_N  Year
# 4497  A series of incidents in Afghanistan set compl... 2020-08-14  2020
# 6437  Trapped at a stagecoach stop as a storm rages ... 2020-08-14  2020

# %%
data[(data["Category"] == "TV Show") & (data["Rating"] == "R") & (data["Year"] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#          Release_Date Rating  Duration  \
# 4497  August 14, 2020      R  1 Season
# 6437  August 14, 2020      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_N  Year
# 4497  A series of incidents in Afghanistan set compl... 2020-08-14  2020
# 6437  Trapped at a stagecoach stop as a storm rages ... 2020-08-14  2020

# %% [markdown]
# ##### Question (10) What is the maximum duration of a Movie/Show on Netflix ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
# data["Duration"].unique()
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data["Duration"].dtypes
# Out:
# dtype('O')

# %%
#splitting the duration using str.split method
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020

# %%
data[["Minutes", "Unit"]] = data["Duration"].str.split(" ", expand = True)

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#       Release_Date Rating   Duration  \
# 0  August 14, 2020  TV-MA  4 Seasons
# 1  August 14, 2020  TV-MA     93 min
# 2  August 14, 2020      R     78 min
# 3  August 14, 2020  PG-13     80 min
# 4  August 14, 2020  PG-13    123 min
#
# ...

# %%
# To find the maximum duration
data["Minutes"].max()
# Out:
# '99'

# %% [markdown]
# ##### Question (11) Which individual country has the Highest No. of TV Shows ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year Minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020      93
#
#       Unit
# 0  Seasons
# 1      min

# %%
# create a new data_frame that contain only TV Show
data_tvshow = data[data["Category"] == "TV Show"]

# %%
data_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N  Year Minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
# 5  A genetics professor experiments with a treatm... 2020-08-14  2020       1
#
#       Unit
# 0  Seasons
# 5   Season

# %%
# to count the number of TV Show
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
# To show the first country only
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ##### Question (12) How can we sort the dataset by Year ?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N  Year Minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020       4
# 1  After a devastating earthquake hits Mexico Cit... 2020-08-14  2020      93
#
#       Unit
# 0  Seasons
# 1      min

# %%
data.sort_values(by = "Country", ascending = False)
# Out:
#      Show_Id Category              Title  \
# 1493   s1494    Movie           Cook Off
# 2757   s2758    Movie  Hitler - A Career
# 939     s940    Movie      Bitcoin Heist
# 1482   s1483    Movie   Conjuring Spirit
# 3105   s3106    Movie            Jackpot
# ...      ...      ...                ...
# 7741   s7740    Movie    Your Excellency
# 7748   s7747  TV Show       دفعة القاهرة
# 7767   s7766    Movie          Zero Hour
# 7779   s7778  TV Show        Zombie Dumb
# 7786   s7785    Movie  Zulu Man in Japan
#
#                                    Director  \
# 1493                        Tomas Brickhill
# 2757  Joachim Fest, Christian Herrendoerfer
# 939                                Ham Tran
# 1482                            Van M. Pham
# 3105                          Dustin Nguyen
# ...                                     ...
# 7741                         Funke Akindele
# 7748                                    NaN
# 7767                       Robert O. Peters
# ...

# %%
data.sort_values(by = "Country", ascending = False).head(2)
# Out:
#      Show_Id Category              Title  \
# 1493   s1494    Movie           Cook Off
# 2757   s2758    Movie  Hitler - A Career
#
#                                    Director  \
# 1493                        Tomas Brickhill
# 2757  Joachim Fest, Christian Herrendoerfer
#
#                                                    Cast       Country  \
# 1493  Tendaiishe Chitima, Tendai Nguni, Jesese Mungo...      Zimbabwe
# 2757                                                NaN  West Germany
#
#          Release_Date Rating Duration  \
# 1493  August 14, 2020   TV-G  100 min
# 2757  August 14, 2020  TV-MA  150 min
#
#                                                  Type  \
# 1493  Comedies, International Movies, Romantic Movies
# 2757              Documentaries, International Movies
#
#                                             Description     Date_N  Year  \
# 1493  Yearning for a better life, a single mother wi... 2020-08-14  2020
# ...

# %% [markdown]
# ##### Question (13) Find all the instances where:

# %% [markdown]
# ##### Category is 'Movie' and Type is 'Dramas'.

# %% [markdown]
# ##### or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
# Category is 'Movie' and Type is 'Dramas'.
data[(data["Category"] == "Movie") & (data["Type"] == "Dramas")]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data["Category"] == "Movie") & (data["Type"] == "Dramas")].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#       Release_Date Rating Duration    Type  \
# 4  August 14, 2020  PG-13  123 min  Dramas
# 7  August 14, 2020      R  119 min  Dramas
#
#                                          Description     Date_N  Year Minutes  \
# 4  A brilliant group of students become card-coun... 2020-08-14  2020     123
# 7  After one of his high school students attacks ... 2020-08-14  2020     119
#
#   Unit
# 4  min
# 7  min

# %%
##### or Category is 'TV Show' & Type is 'Kids' TV'.
data[(data["Category"] == "TV Show") & (data["Type"] == "Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
data[(data["Category"] == "TV Show") & (data["Type"] == "Kids' TV")].head(2)
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#         Release_Date Rating   Duration      Type  \
# 111  August 14, 2020  TV-Y7  2 Seasons  Kids' TV
# 276  August 14, 2020   TV-Y   1 Season  Kids' TV
#
#                                            Description     Date_N  Year  \
# 111  Paw-esome tales abound when singing furry frie... 2020-08-14  2020
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-08-14  2020
#
#     Minutes     Unit
# 111       2  Seasons
# 276       1   Season

# %%
data[(data["Category"] == "Movie") & (data["Type"] == "Dramas") | (data["Category"] == "TV Show") & (data["Type"] == "Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
